# %%
# You may not need to run this cell, start by skipping it 
# !pip install -U pip
# !pip install -U --no-warn-script-location langchain langchain-community langchain-openai
# run once and then restart your kernel
# Out:
# Requirement already satisfied: pip in /opt/homebrew/lib/python3.11/site-packages (24.3.1)
# Requirement already satisfied: langchain in /opt/homebrew/lib/python3.11/site-packages (0.3.9)
# Requirement already satisfied: langchain-community in /opt/homebrew/lib/python3.11/site-packages (0.3.9)
# Requirement already satisfied: langchain-openai in /opt/homebrew/lib/python3.11/site-packages (0.2.10)
# Requirement already satisfied: PyYAML>=5.3 in /opt/homebrew/lib/python3.11/site-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/homebrew/lib/python3.11/site-packages (from langchain) (2.0.30)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/homebrew/lib/python3.11/site-packages (from langchain) (3.9.3)
# Requirement already satisfied: langchain-core<0.4.0,>=0.3.21 in /opt/homebrew/lib/python3.11/site-packages (from langchain) (0.3.21)
# Requirement already satisfied: langchain-text-splitters<0.4.0,>=0.3.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain) (0.3.2)
# Requirement already satisfied: langsmith<0.2.0,>=0.1.17 in /opt/homebrew/lib/python3.11/site-packages (from langchain) (0.1.147)
# Requirement already satisfied: numpy<2,>=1.22.4 in /opt/homebrew/lib/python3.11/site-packages (from langchain) (1.25.2)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /opt/homebrew/lib/python3.11/site-packages (from langchain) (2.10.2)
# Requirement already satisfied: requests<3,>=2 in /opt/homebrew/lib/python3.11/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain) (8.3.0)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /opt/homebrew/lib/python3.11/site-packages (from langchain-community) (0.6.6)
# Requirement already satisfied: httpx-sse<0.5.0,>=0.4.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain-community) (2.6.1)
# Requirement already satisfied: openai<2.0.0,>=1.54.0 in /opt/homebrew/lib/python3.11/site-packages (from langchain-openai) (1.56.0)
# Requirement already satisfied: tiktoken<1,>=0.7 in /opt/homebrew/lib/python3.11/site-packages (from langchain-openai) (0.7.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/homebrew/lib/python3.11/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /opt/homebrew/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.21.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /opt/homebrew/lib/python3.11/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /opt/homebrew/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /opt/homebrew/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain) (23.2)
# Requirement already satisfied: typing-extensions>=4.7 in /opt/homebrew/lib/python3.11/site-packages (from langchain-core<0.4.0,>=0.3.21->langchain) (4.12.2)
# Requirement already satisfied: httpx<1,>=0.23.0 in /opt/homebrew/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (0.26.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /opt/homebrew/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (3.9.14)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /opt/homebrew/lib/python3.11/site-packages (from langsmith<0.2.0,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /opt/homebrew/lib/python3.11/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (4.0.0)
# Requirement already satisfied: distro<2,>=1.7.0 in /opt/homebrew/lib/python3.11/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /opt/homebrew/lib/python3.11/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (0.8.0)
# Requirement already satisfied: sniffio in /opt/homebrew/lib/python3.11/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (1.3.0)
# Requirement already satisfied: tqdm>4 in /opt/homebrew/lib/python3.11/site-packages (from openai<2.0.0,>=1.54.0->langchain-openai) (4.66.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /opt/homebrew/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.6.0)
# Requirement already satisfied: pydantic-core==2.27.1 in /opt/homebrew/lib/python3.11/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.27.1)
# Requirement already satisfied: python-dotenv>=0.21.0 in /opt/homebrew/lib/python3.11/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.0.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/homebrew/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/homebrew/lib/python3.11/site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/homebrew/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/homebrew/lib/python3.11/site-packages (from requests<3,>=2->langchain) (2024.8.30)
# Requirement already satisfied: regex>=2022.1.18 in /opt/homebrew/lib/python3.11/site-packages (from tiktoken<1,>=0.7->langchain-openai) (2023.10.3)
# Requirement already satisfied: httpcore==1.* in /opt/homebrew/lib/python3.11/site-packages (from httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (1.0.2)
# Requirement already satisfied: h11<0.15,>=0.13 in /opt/homebrew/lib/python3.11/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.2.0,>=0.1.17->langchain) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /opt/homebrew/lib/python3.11/site-packages (from jsonpatch<2.0,>=1.33->langchain-core<0.4.0,>=0.3.21->langchain) (2.4)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/homebrew/lib/python3.11/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)

# %%
import requests
from langchain_community.document_loaders import BSHTMLLoader
from langchain_core.pydantic_v1 import BaseModel, Field
from typing import List, Optional
from langchain_core.prompts import ChatPromptTemplate, MessagesPlaceholder
from langchain_openai import ChatOpenAI
import pandas as pd

### This cell may generate a warning message that is ok.
# Out:
# /opt/homebrew/lib/python3.11/site-packages/IPython/core/interactiveshell.py:3526: LangChainDeprecationWarning: As of langchain-core 0.3.0, LangChain uses pydantic v2 internally. The langchain_core.pydantic_v1 module was a compatibility shim for pydantic v1, and should no longer be used. Please update the code to import from Pydantic directly.
#
# For example, replace imports like: `from langchain_core.pydantic_v1 import BaseModel`
# with: `from pydantic import BaseModel`
# or the v1 compatibility namespace if you are working in a code base that has not been fully upgraded to pydantic 2 yet. 	from pydantic.v1 import BaseModel
#
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
data = requests.get('https://courses.cs.washington.edu/courses/cse163/20wi/files/lectures/L04/bee-movie.txt')
f = open('source.html','w')
f.write(data.text)
f.close()
soup = BSHTMLLoader('source.html').load()

# %%
class CharacterTraits(BaseModel):
    """Information about the traits of various characters in the Bee Movie"""
    character: str = Field(description="The name of the character")
    bee: Optional[bool] = Field(description="Whether the character is a bee")
    trait: str = Field(description="The trait of the character")
    proof: str = Field(description="A verbatim quote from the movie that demonstrates the trait")
    good: bool = Field(description="Whether the trait is good or bad")
    confidence: float = Field(description="How confident you are that the character has this trait, from 0 to 1")


class Data(BaseModel):
    traits: List[CharacterTraits]

# %%
prompt = ChatPromptTemplate.from_messages(
    [
        (
            "system",
            "You are an expert at finding historical events in text.  I have a text that I would like you to analyze.  The text is about the Bee Movie.  Can you extract the historical events from the text?"
            "only extract important characters and their traits"
        ),
        ("human","{text}" )
    ]
)

llm = ChatOpenAI(model_name="gpt-4o", temperature=0)
extract = prompt | llm.with_structured_output(schema=Data, method="function_calling")

## Setup complete lets do the work

from langchain_text_splitters import TokenTextSplitter
textsplit = TokenTextSplitter(
    chunk_size=2000,
    chunk_overlap=30
)

content = textsplit.split_text(soup[0].page_content)
events = extract.batch(
    [{"text":text} for text in content],
    {"max_concurrency": 2}
    )




all_events = []

for i in events:
    all_events.extend(i.traits)
f = open("out.csv",'w')
for event in all_events:
    print(event)
    # Print the results to out.csv
    f.write(f"{event.character},{event.bee},{event.trait},{event.proof},{event.good},{event.confidence}\n")
# Out:
# character='Barry Benson' bee=True trait='Nonconformist' proof="The bee, of course, flies anyway because bees don't care what humans think is impossible." good=True confidence=0.9
# character='Barry Benson' bee=True trait='Adventurous' proof="I'm glad I took a day and hitchhiked around the hive." good=True confidence=0.8
# character='Barry Benson' bee=True trait='Curious' proof='You ever think maybe things work a little too well here?' good=True confidence=0.85
# character='Adam Flayman' bee=True trait='Conventional' proof="Why would you question anything? We're bees. We're the most perfectly functioning society on Earth." good=False confidence=0.8
# character='Janet Benson' bee=True trait='Caring' proof="Very proud. (Rubs Barry's hair)" good=True confidence=0.9
# character='Martin Benson' bee=True trait='Proud' proof="Here's the graduate. We're very proud of you, son." good=True confidence=0.85
# character='Dean Buzzwell' bee=True trait='Authoritative' proof='Welcome, New Hive City graduating class of...' good=True confidence=0.8
# character='Tour Guide' bee=True trait='Informative' proof='Welcome to Honex, a division of Honesco and a part of the Hexagon Group.' good=True confidence=0.9
# character='Barry' bee=True trait='Curious and questioning' proof='You ever think maybe things work a little too well here?' good=True confidence=0.9
# character='Adam' bee=True trait='Skeptical' proof='Like what? Give me one example.' good=True confidence=0.8
# character='Pollen Jocks' bee=True trait='Adventurous and brave' proof="They know what it's like outside the hive." good=True confidence=0.9
# character='Lou Lo Duva' bee=True trait='Encouraging and enthusiastic' proof="You guys did great! You're monsters! You're sky freaks! I love it!" good=True confidence=0.9
# character='Martin' bee=True trait='Traditional and set in his ways' proof="You're not funny! You're going into honey. Our son, the stirrer!" good=False confidence=0.8
# character='Janet' bee=True trait='Proud and dismissive' proof='Barry, you are so funny sometimes.' good=False confidence=0.7
# character='Barry B. Benson' bee=True trait='adventurous' proof='I have to, before I go to work for the rest of my life.' good=True confidence=0.9
# character='Barry B. Benson' bee=True trait='brave' proof="You're gonna die! You're crazy!" good=True confidence=0.8
# character='Lou Lo Duva' bee=True trait='authoritative' proof="Hold it, son, flight deck's restricted." good=True confidence=0.85
# character='Pollen Jock #1' bee=True trait='experienced' proof='Ever see pollination up close?' good=True confidence=0.9
# character='Pollen Jock #2' bee=True trait='cautious' proof="Careful, guys. It's a little grabby." good=True confidence=0.8
# character='Vanessa Bloome' bee=False trait='unaware' proof='Vanessa Bloome starts bouncing the tennis ball, not knowing Barry is stick to it.' good=False confidence=0.7
# character='Barry' bee=True trait='Curious and adventurous' proof="I can't believe I'm doing this. I've got to." good=True confidence=0.9
# character='Vanessa' bee=None trait='Compassionate and empathetic' proof="Don't kill him!" good=True confidence=0.95
# character='Ken' bee=None trait='Self-centered and dismissive' proof='Why does his life have any less value than mine? Is that your statement?' good=False confidence=0.85
# character='Vanessa' bee=None trait='Open-minded' proof="I'm talking to a bee. And the bee is talking to me!" good=True confidence=0.9
# character='Barry' bee=True trait='Grateful' proof="I just want to say I'm grateful." good=True confidence=0.95
# character='Ken' bee=None trait='Insecure' proof="When I leave a job interview, they're flabbergasted, can't believe what I say." good=False confidence=0.8
# character='Barry' bee=True trait='Curious and adventurous' proof="BARRY: Humans! I can't believe you were with humans!" good=True confidence=0.9
# character='Vanessa' bee=None trait='Kind and hospitable' proof="VANESSA: It's no trouble. It takes two minutes." good=True confidence=0.9
# character='Adam' bee=True trait='Cautious and concerned' proof='ADAM: You did it, and I\'m glad. You saw whatever you wanted to see. You had your "experience." Now you can pick out your job and be normal.' good=True confidence=0.8
# character='Vanessa' bee=None trait='Supportive and understanding' proof='VANESSA: I know how you feel.' good=True confidence=0.8
# character='Barry' bee=True trait='Nonconformist' proof="BARRY: I want to do my part for the hive, but I can't do it the way they want." good=True confidence=0.85
# character='Adam' bee=True trait='Skeptical' proof="ADAM: No, no. That's a bee law. You wouldn't break a bee law." good=True confidence=0.75
# character='Barry' bee=None trait='Yearning' proof='Yes, but who can deny the heart that is yearning?' good=False confidence=0.8
# character='Adam' bee=None trait='Practical' proof='You have got to start thinking bee, my friend. Thinking bee!' good=True confidence=0.9
# character='Martin' bee=None trait='Critical' proof="What life? You have no life! You have no job. You're barely a bee!" good=False confidence=0.85
# character='Vanessa' bee=None trait='Adventurous' proof='Watch this!' good=True confidence=0.9
# character='Vanessa' bee=None trait='Protective' proof="He's not bothering anybody. Get out of here, you creep!" good=True confidence=0.95
# character='Barry' bee=None trait='Curious' proof='What in the name of Mighty Hercules is this?' good=True confidence=0.9
# character='Barry' bee=None trait='Determined' proof="I'm getting to the bottom of all of this!" good=True confidence=0.95
# character='Barry B. Benson' bee=True trait='Curious and investigative' proof='BARRY: Where is the honey coming from? Tell me where!' good=True confidence=0.9
# character='Hector' bee=False trait='Deceptive' proof="HECTOR: Well, I guess I'll go home now and just leave this nice honey out, with no one around." good=False confidence=0.8
# character='Mooseblood' bee=False trait='Survivor and opportunistic' proof='MOOSEBLOOD: Do I look dead? They will wipe anything that moves. Where you headed?' good=True confidence=0.85
# character='Beekeeper #1' bee=False trait='Exploitative' proof='BEEKEEPER #1: They make the honey, and we make the money.' good=False confidence=0.9
# character='Beekeeper #2' bee=False trait='Exploitative' proof='BEEKEEPER #2: They make the honey, and we make the money.' good=False confidence=0.9
# character='Barry Benson' bee=True trait='Determined' proof='BARRY: I want to do it for all our lives. Nobody works harder than bees!' good=True confidence=0.9
# character='Barry Benson' bee=True trait='Courageous' proof='BARRY: Bees have never been afraid to change the world.' good=True confidence=0.9
# character='Barry Benson' bee=True trait='Rebellious' proof='BARRY: The bees!' good=False confidence=0.8
# character='Vanessa' bee=False trait='Supportive' proof="VANESSA: I'm helping him sue the human race." good=True confidence=0.9
# character='Vanessa' bee=False trait='Empathetic' proof='VANESSA: You poor thing. You two have been at this for hours!' good=True confidence=0.8
# character='Ken' bee=False trait='Competitive' proof='KEN: In tennis, you attack at the point of weakness!' good=False confidence=0.7
# character='Ken' bee=False trait='Jealous' proof='KEN: Why is yogurt night so difficult?!' good=False confidence=0.6
# character='Adam' bee=True trait='Skeptical' proof="ADAM: Even if it's true, what can one bee do?" good=False confidence=0.7
# character='Uncle Carl' bee=True trait='Humorous' proof='UNCLE CARL: I dated a cricket once in San Antonio. Those crazy legs kept me up all night.' good=True confidence=0.8
# character='Layton Montgomery' bee=None trait='Fat' proof='A limousine drives up and a fat man, Layton Montgomery, a honey industry owner gets out and walks past Barry' good=False confidence=0.8
# character='Barry Bee Benson' bee=True trait='Determined' proof="I'm hoping that, after this is all over, you'll see how, by taking our honey, you not only take everything we have but everything we are!" good=True confidence=0.9
# character='Judge Bumbleton' bee=None trait='Authoritative' proof='Order in this court!' good=True confidence=0.8
# character='Klauss Vanderhayden' bee=None trait='Owner of big company' proof='So, Mr. Klauss Vanderhayden of Honey Farms, big company you have.' good=False confidence=0.7
# character='Mr. Sting' bee=None trait='Famous musician' proof='I was with a band called The Police.' good=True confidence=0.9
# character='Ray Liotta' bee=None trait='Devilishly handsome with inner turmoil' proof="I see from your resume that you're devilishly handsome with a churning inner turmoil that's ready to blow." good=False confidence=0.8
# character='Vanessa' bee=None trait='Supportive' proof="I think the jury's on our side." good=True confidence=0.8
# character='Ken' bee=None trait='Jealous' proof='Ken walks in from work. He sees Barry and he looks upset when he sees Barry clinking his glass with Vanessa.' good=False confidence=0.8
# character='Barry Benson' bee=True trait='Empathetic' proof='I know how hard it is to find the right job. We have that in common.' good=True confidence=0.9
# character='Ken' bee=None trait='Aggressive' proof="You know, you know I've just about had it with your little mind games." good=False confidence=0.9
# character='Vanessa' bee=None trait='Supportive' proof="And he happens to be the nicest bee I've met in a long time!" good=True confidence=0.9
# character='Montgomery' bee=None trait='Antagonistic' proof="Don't worry. The only thing I have to do to turn this jury around is to remind them of what they don't like about bees." good=False confidence=0.9
# character='Adam' bee=True trait='Impulsive' proof="I'm going to pincushion this guy!" good=False confidence=0.8
# character='Montgomery' bee=None trait='Overreacting' proof="Oh, I'm hit!! Oh, lordy, I am hit! The venom! The venom is coursing through my veins! I have been felled by a winged beast of destruction!" good=False confidence=0.9
# character='Judge Bumbleton' bee=None trait='Authoritative' proof='I will have order in this court. Order! Order, please!' good=True confidence=0.8
# character='Adam' bee=None trait='Self-doubt' proof="I blew the whole case, didn't I? I'd be better off dead. Look at me." good=False confidence=0.7
# character='Barry' bee=None trait='Supportive' proof="It doesn't matter. What matters is you're alive. You could have died." good=True confidence=0.9
# character='Barry' bee=None trait='Determined' proof="Get dressed. I've gotta go somewhere. Get back to the court and stall. Stall any way you can." good=True confidence=0.8
# character='Montgomery' bee=None trait='Dismissive' proof="Your Honor, haven't these ridiculous bugs taken up enough of this court's valuable time?" good=False confidence=0.8
# character='Barry' bee=None trait='Resourceful' proof='Hold it, Your Honor! You want a smoking gun? Here is your smoking gun.' good=True confidence=0.9
# character='Vanessa' bee=None trait='Supportive' proof='Vanessa, we won! I knew you could do it! High-five!' good=True confidence=0.8
# character='Barry B. Benson' bee=True trait='Determined' proof='BARRY: OK, I made a huge mistake. This is a total disaster, all my fault.' good=True confidence=0.9
# character='Vanessa Bloome' bee=None trait='Caring' proof='VANESSA: I know this is also partly my fault.' good=True confidence=0.8
# character='Dean Buzzwell' bee=True trait='Authoritative' proof='DEAN BUZZWELL: Stop making honey!' good=True confidence=0.85
# character='Adam Flayman' bee=True trait='Reflective' proof="ADAM: Sometimes I think, so what if humans liked our honey? Who wouldn't?" good=True confidence=0.75
# character='Sniper' bee=None trait='Efficient' proof="SNIPER: He'll have nausea for a few hours, then he'll be fine." good=True confidence=0.7
# character='Barry Benson' bee=True trait='Resourceful' proof='BARRY: I have an idea.' good=True confidence=0.9
# character='Vanessa Bloome' bee=None trait='Supportive' proof='VANESSA: I think this is gonna work.' good=True confidence=0.8
# character='Barry Benson' bee=True trait='Brave' proof='BARRY: I gotta get up there and talk to them.' good=True confidence=0.9
# character='Vanessa Bloome' bee=None trait='Courageous' proof="VANESSA: I can't fly a plane. BARRY: - Why not? Isn't John Travolta a pilot? VANESSA: - Yes." good=True confidence=0.8
# character='Captain Scott' bee=None trait='Panicky' proof='CAPTAIN SCOTT: Bee!' good=False confidence=0.7
# character='Bud Ditchwater' bee=None trait='Skeptical' proof="BUD: I'm quite familiar with Mr. Benson and his no-account compadres." good=False confidence=0.8
# character='Barry B. Benson' bee=True trait='Leadership' proof="That's why I want to get bees back to working together. That's the bee way!" good=True confidence=0.9
# character='Vanessa Bloome' bee=False trait='Bravery' proof='So it turns out I cannot fly a plane.' good=True confidence=0.8
# character='Lou Lu Duva' bee=True trait='Supportive' proof="All of you, let's get behind this fellow! Move it out!" good=True confidence=0.85
# character='Pollen Jocks' bee=True trait='Teamwork' proof='All of the Pollen Jocks are carrying the plane.' good=True confidence=0.9
# character='Barry B. Benson' bee=True trait='Determination' proof="If we're gonna survive as a species, this is our moment! What do you say?" good=True confidence=0.9
# character='Barry B. Benson' bee=True trait='Adventurous' proof="I'm a Pollen Jock! And it's a perfect fit. All I gotta do are the sleeves." good=True confidence=0.9
# character='Barry B. Benson' bee=True trait='Helpful' proof='No problem, Vannie. Just leave it to me.' good=True confidence=0.9
# character='Barry B. Benson' bee=True trait='Reluctant to make hasty decisions' proof="I'm not making a major life decision during a production number!" good=True confidence=0.8
# character='Vanessa Bloome' bee=None trait='Supportive' proof="You're a lifesaver, Barry." good=True confidence=0.9
# character='Mooseblood' bee=None trait='Humorous' proof="Ma'am, I was already a blood-sucking parasite. All I needed was a briefcase." good=True confidence=0.8
# character='Ken' bee=None trait='Jealous' proof='That bee is living my life!!' good=False confidence=0.9
